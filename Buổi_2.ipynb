# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhtiendat2k3/bai-tap/blob/main/Bu%E1%BB%95i_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# %matplotlib inline

# %%
import pandas as pd


url = "https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/chipotle.tsv"

# Sử dụng pandas để đọc dữ liệu
data = pd.read_csv(url, sep='\t')

print(data.head())
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
data.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
# Kiểm tra dữ liệu thiếu
print(data.isnull().sum())
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
# Tính giá trị trung bình của cột 'choice_description'
average_choice_description = data['choice_description'].mode()[0]

# Thay thế các giá trị thiếu trong cột 'choice_description' bằng giá trị trung bình
data['choice_description'].fillna(average_choice_description, inplace=True)

# %%
# Chuẩn hóa dữ liệu
data['item_name'] = data['item_name'].str.lower()  # Chuyển tất cả thành chữ thường

# %%
# Xử lý dữ liệu lặp lại hoặc không cần thiết
data.drop_duplicates(inplace=True)  # Loại bỏ các hàng trùng lặp

# %%
# Đếm số lượng mỗi giá trị trong cột 'choice_description'
choice_counts = chipotle_data['choice_description'].value_counts()

# Chọn số lượng hàng để hiển thị trong biểu đồ
top_choices = choice_counts.head(10)

# Vẽ biểu đồ cột
plt.figure(figsize=(10,6))
top_choices.plot(kind='bar')
plt.title('Top 10 Choice Descriptions')
plt.xlabel('Choice Description')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# Biểu đồ barchart thể hiện sự so sánh về độ yêu thích giữa các món ăn được chọn. cho ta thấy được sự ưa chuộng của khách hàng và các lựa chọn thường xuyên của khách hàng. từ đó có thể rút ra chiến lược kinh doanh
