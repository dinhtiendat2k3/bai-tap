# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhtiendat2k3/bai-tap/blob/main/Bu%C3%B4%CC%89i_7_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/ruchitgandhi/Twitter-Airline-Sentiment-Analysis/master/Tweets.csv')

# %%
df.head()
# Out:
#                 tweet_id airline_sentiment  airline_sentiment_confidence  \
# 4206  567778009013178368          negative                        1.0000
# 9536  569887533267611648          negative                        0.8563
#
#         negativereason  negativereason_confidence     airline  \
# 4206  Cancelled Flight                     1.0000      United
# 9536       Late Flight                     0.5938  US Airways
#
#      airline_sentiment_gold             name negativereason_gold  \
# 4206               negative    realmikesmith    Cancelled Flight
# 9536               negative  ConstanceSCHERE         Late Flight
#
#       retweet_count                                               text  \
# 4206              0  @united So what do you offer now that my fligh...
# 9536              0  @USAirways Seriously doubt that as I am still ...
#
#                       tweet_coord              tweet_created tweet_location  \
# ...

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import string

# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %% [markdown]
# Tiền xử lí dữ liệu

# %%
# Loại bỏ các dòng trống
df.dropna(inplace=True)

# %%
# Chuẩn hóa văn bản và loại bỏ dấu câu
text = text.lower()  # Chuyển đổi thành chữ thường
text = text.translate(str.maketrans('', '', string.punctuation))  # Loại bỏ dấu câu

# %%
# Tách từ trong văn bản
words = word_tokenize(text)

# %%
# Loại bỏ stop words và các từ chỉ chứa một chữ cái
stop_words = set(stopwords.words('english'))
filtered_words = [word for word in words if (word not in stop_words) and len(word) > 1]

# %%
# Tạo WordCloud từ chuỗi văn bản đã tiền xử lý
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(words))

# %%
# Hiển thị WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# 1 số từ xuất hiện nhiều và nổi bật nhất : time, US, canada, flight, service, thank
