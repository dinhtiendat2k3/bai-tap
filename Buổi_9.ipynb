# %% [markdown]
# <a href="https://colab.research.google.com/github/dinhtiendat2k3/bai-tap/blob/main/Bu%E1%BB%95i_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/car_crashes.csv')

# %%
df.head(5)
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
columns = ['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous', 'ins_premium', 'ins_losses']

for column in columns:
    plt.figure(figsize=(8, 6))
    df.boxplot(column=[column])
    plt.title(f'Boxplot of {column}')
    plt.ylabel('Values')
    plt.show()

# %% [markdown]
# Bài 2

# %%
data = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/Online_Retail.csv', encoding='latin1')

# %%
data.head(10)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 5    536365     22752         SET 7 BABUSHKA NESTING BOXES         2
# 6    536365     21730    GLASS STAR FROSTED T-LIGHT HOLDER         6
# 7    536366     22633               HAND WARMER UNION JACK         6
# 8    536366     22632            HAND WARMER RED POLKA DOT         6
# 9    536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
#
#     InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/10 8:26       2.55     17850.0  United Kingdom
# 1  12/1/10 8:26       3.39     17850.0  United Kingdom
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Vẽ biểu đồ box plot cho cột UnitPrice và Quantity theo nhóm quốc gia
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Country', y='UnitPrice')
plt.title('Box Plot of Unit Price by Country')
plt.xticks(rotation=90)  # Xoay nhãn trục x nếu cần thiết
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x='Country', y='Quantity')
plt.title('Box Plot of Quantity by Country')
plt.xticks(rotation=90)  # Xoay nhãn trục x nếu cần thiết
plt.show()

# %% [markdown]
# khó để nhận xét vì số nước nhiều.
# (Chọn ra 2 nước có chỉ số về UnitPrice và Quantity với biên độ nhỏ để so sánh)

# %%
dulieu = data[data['Country'].isin(['Saudi Arabia', 'Lebanon'])]

plt.figure(figsize=(12, 6))
sns.boxplot(data=dulieu, x='Country', y='UnitPrice')
plt.title('Box Plot of Unit Price by Country')
plt.xticks(rotation=90)  # Xoay nhãn trục x nếu cần thiết
plt.show()

plt.figure(figsize=(12, 6))
sns.boxplot(data=dulieu, x='Country', y='Quantity')
plt.title('Box Plot of Quantity by Country')
plt.xticks(rotation=90)  # Xoay nhãn trục x nếu cần thiết
plt.show()

# %% [markdown]
# _ UnitPrice
# Trung vị : Lebanon có dữ liệu tập chung chủ yếu ở 4 , của Ả Rập là 2. dựa vào đường trung vị ta thấy được phân bố dữ liệu của Ả Rập đều hơn Lebanon
# Hộp dữ liệu của Ả Rập nhỏ hơn Lebanon. Cho thấy độ biến động dữ liệu của Ả Rập nhỏ hơn
# Dữ liệu của Lebanon phân tán rộng hơn Ả Rập và phân bố chủ yếu vào bên dưới khaongr từ 2 đến 8 . Ả rập có độ phân tán ít hơn , tập dữ liệu phân bố chủ yếu trong khoảng 2 - 4
# _ Quantity: cả 2 taaho dữ liệu khá tương đồng về đường trung vị cũng như độ phân tán. duy chỉ có phần râu thì Lebanon phân bố đều và tập trung ở vùng gần trung vị hơn
